# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data importation and cleaning

# %%
# EL archivo parquet es más liviano que un CSV y ayuda a agilizar el analisis
df = pd.read_parquet(r'C:\Users\mirko\Desktop\EK\JyJ\artroplastia rodilla PAD\Egresos Hospitalarios\cleaned_data\Egresos_2001-2020.parquet')

# %% [markdown]
# Basic information about the data

# %%
# A quick view of the data
df.head()
# Out:
#      SEXO  EDAD_A_OS PREVISION PERTENENCIA_ESTABLECIMIENTO_SALUD  \
# 0  Hombre         60    Fonasa                           Privado
# 1  Hombre         74    Fonasa                           Publico
# 2  Hombre         71    Fonasa                           Publico
# 3  Hombre          2    Fonasa                           Publico
# 4  Hombre         81    Fonasa                           Publico
#
#                      GLOSA_ESTABLECIMIENTO_SALUD  DIAS_ESTADA  \
# 0                               Clínica Familia             2
# 1  Hospital Del Salvador (Santiago, Providencia)           58
# 2  Hospital Del Salvador (Santiago, Providencia)           12
# 3   Instituto de Neurocirugía Dr. Alfonso Asenjo            1
# 4     Hospital Dr. Leonardo Guzmán (Antofagasta)            7
#
#   CONDICION_EGRESO DIAG1                                        GLOSA_DIAG1  \
# 0           Muerto  C780                TUMOR MALIGNO SECUNDARIO DEL PULMÓN
# ...

# %%
# Los tipos de datos de cada columna fueron esteblecidos en la importación
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26337902 entries, 0 to 26337901
# Data columns (total 10 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   SEXO                               category
#  1   EDAD_A_OS                          int32
#  2   PREVISION                          category
#  3   PERTENENCIA_ESTABLECIMIENTO_SALUD  category
#  4   GLOSA_ESTABLECIMIENTO_SALUD        object
#  5   DIAS_ESTADA                        int32
#  6   CONDICION_EGRESO                   category
#  7   DIAG1                              object
#  8   GLOSA_DIAG1                        object
#  9   Año                                int32
# dtypes: category(4), int32(3), object(3)
# memory usage: 1004.7+ MB

# %%
# Todos los datos nulos fueron eliminados en la importación
df.isnull().sum()
# Out:
# SEXO                                 0
# EDAD_A_OS                            0
# PREVISION                            0
# PERTENENCIA_ESTABLECIMIENTO_SALUD    0
# GLOSA_ESTABLECIMIENTO_SALUD          0
# DIAS_ESTADA                          0
# CONDICION_EGRESO                     0
# DIAG1                                0
# GLOSA_DIAG1                          0
# Año                                  0
# dtype: int64

# %%
df.shape
# Out:
# (26337902, 10)

# %% [markdown]
# Fixing missing or incorrect values (outilers, duplicates)

# %%
df[df.duplicated(keep=False)]
# Out:
#             SEXO  EDAD_A_OS PREVISION PERTENENCIA_ESTABLECIMIENTO_SALUD  \
# 9         Hombre          0    Fonasa                           Publico
# 40        Hombre         66    Fonasa                           Publico
# 41        Hombre         69    Fonasa                           Publico
# 43        Hombre         66    Fonasa                           Publico
# 44        Hombre         69    Fonasa                           Publico
# ...          ...        ...       ...                               ...
# 26337885   Mujer         33    Fonasa                           Publico
# 26337886  Hombre         14    Fonasa                           Publico
# 26337892   Mujer         53    Fonasa                           Publico
# 26337897   Mujer         49    Fonasa                           Publico
# 26337898   Mujer         49    Fonasa                           Publico
#
#                              GLOSA_ESTABLECIMIENTO_SALUD  DIAS_ESTADA  \
# ...

# %% [markdown]
# ## Exploratory analysis and visualizations with matplotlib and seaborn

# %% [markdown]
# ## Preguntas que surjan

# %% [markdown]
# 1. ¿Cual es la tendencia en la evolución de la prevalencia de los problemas de salud a lo largo de los años?
# 2. dfsdf
# 3. dsf
# 4. sdf
# 5. sd
